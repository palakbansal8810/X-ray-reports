# %%
import os
from torchvision import datasets, transforms
from sklearn.model_selection import train_test_split

# Define the directory containing your dataset
dataset_dir = 'data_fracture/val'

# Define the transformation (optional, adjust based on your needs)
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor()
])

# Load the dataset
full_dataset = datasets.ImageFolder(root=dataset_dir, transform=transform)

# Split the dataset into validation and test sets
val_size = int(0.8 * len(full_dataset))  # 80% for validation
test_size = len(full_dataset) - val_size  # Remaining 20% for test

val_dataset, test_dataset = train_test_split(full_dataset, test_size=test_size, random_state=42)

# Create DataLoaders for validation and test sets (optional, adjust batch size as needed)
from torch.utils.data import DataLoader

val_loader = DataLoader(val_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
test
# Out:
#                                                  image          label
# 0    data_fracture/val\fractured\1-rotated1-rotated...      fractured
# 1    data_fracture/val\fractured\1-rotated1-rotated...      fractured
# 2    data_fracture/val\fractured\1-rotated1-rotated...      fractured
# 3    data_fracture/val\fractured\1-rotated1-rotated...      fractured
# 4    data_fracture/val\fractured\1-rotated1-rotated...      fractured
# ..                                                 ...            ...
# 595  data_fracture/val\not fractured\4-rotated2-rot...  not fractured
# 596  data_fracture/val\not fractured\4-rotated2-rot...  not fractured
# 597  data_fracture/val\not fractured\4-rotated2-rot...  not fractured
# 598     data_fracture/val\not fractured\4-rotated2.jpg  not fractured
# 599              data_fracture/val\not fractured\4.jpg  not fractured
#
# [600 rows x 2 columns]

# %%
train
# Out:
#                                                   image          label
# 0     data_fracture/train\fractured\10-rotated1-rota...      fractured
# 1     data_fracture/train\fractured\10-rotated1-rota...      fractured
# 2     data_fracture/train\fractured\10-rotated1-rota...      fractured
# 3     data_fracture/train\fractured\10-rotated1-rota...      fractured
# 4     data_fracture/train\fractured\10-rotated1-rota...      fractured
# ...                                                 ...            ...
# 8858  data_fracture/train\not fractured\9-rotated3-r...  not fractured
# 8859  data_fracture/train\not fractured\9-rotated3-r...  not fractured
# 8860  data_fracture/train\not fractured\9-rotated3-r...  not fractured
# 8861   data_fracture/train\not fractured\9-rotated3.jpg  not fractured
# 8862            data_fracture/train\not fractured\9.jpg  not fractured
#
# [8863 rows x 2 columns]

# %%
val
# Out:
#                                                  image          label
# 0    data_fracture/val\fractured\1-rotated1-rotated...      fractured
# 1    data_fracture/val\fractured\1-rotated1-rotated...      fractured
# 2    data_fracture/val\fractured\1-rotated1-rotated...      fractured
# 3    data_fracture/val\fractured\1-rotated1-rotated...      fractured
# 4    data_fracture/val\fractured\1-rotated1-rotated...      fractured
# ..                                                 ...            ...
# 595  data_fracture/val\not fractured\4-rotated2-rot...  not fractured
# 596  data_fracture/val\not fractured\4-rotated2-rot...  not fractured
# 597  data_fracture/val\not fractured\4-rotated2-rot...  not fractured
# 598     data_fracture/val\not fractured\4-rotated2.jpg  not fractured
# 599              data_fracture/val\not fractured\4.jpg  not fractured
#
# [600 rows x 2 columns]

# %%
import os 
import cv2
import os 
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import keras 
from keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report

# Read Data
def data(dataset_path):
    images = []
    labels = []
    for subfolder in os.listdir(dataset_path):
        subfolder_path = os.path.join(dataset_path, subfolder)
        if not os.path.isdir(subfolder_path):
            continue
        for image_filename in os.listdir(subfolder_path):
            if image_filename.endswith(".jpg"):
                image_path = os.path.join(subfolder_path, image_filename)
                images.append(image_path)
                labels.append(subfolder)
    df = pd.DataFrame({'image': images, 'label': labels})
    return df
def split_data(df, val_size=0.2, test_size=0.5):
    # Split the data into train+val and test sets
    train_val_df, test_df = train_test_split(df, test_size=test_size, stratify=df['label'], random_state=42)
    # Split the train+val into train and val sets
    train_df, val_df = train_test_split(train_val_df, test_size=val_size, stratify=train_val_df['label'], random_state=42)
    return train_df, val_df, test_df

def create_data_generators(train, test, val):
    image_size = (224, 224)
    batch_size = 32
    datagen = ImageDataGenerator(rescale=1./255)

    train_generator = datagen.flow_from_dataframe(
        train,
        x_col='image',
        y_col='label',
        target_size=image_size,
        batch_size=batch_size,
        class_mode='binary',
        shuffle=True
    )

    test_generator = datagen.flow_from_dataframe(
        test,
        x_col='image',
        y_col='label',
        target_size=image_size,
        batch_size=batch_size,
        class_mode='binary',
        shuffle=False
    )

    val_generator = datagen.flow_from_dataframe(
        val,
        x_col='image',
        y_col='label',
        target_size=image_size,
        batch_size=batch_size,
        class_mode='binary',
        shuffle=True
    )

    return train_generator, test_generator, val_generator

# Modeling
def build_model():
    class_num = 1
    model = keras.models.Sequential()
    model.add(keras.layers.Conv2D(filters=32, kernel_size=(3,3),activation=tf.nn.relu,input_shape=(224,224,3)))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.MaxPool2D((2,2)))  
    model.add(keras.layers.Conv2D(filters=64, kernel_size=(3,3),activation=tf.nn.relu)) 
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.MaxPool2D((2,2))) 
    model.add(keras.layers.Dropout(.3)) 
    model.add(keras.layers.Conv2D(filters=128, kernel_size=(3,3),activation=tf.nn.relu))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.MaxPool2D((2,2))) 
    model.add(keras.layers.Dropout(.3)) 
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(256,activation=tf.nn.relu))
    model.add(keras.layers.Dropout(.3)) 
    model.add(keras.layers.Dense(128,activation=tf.nn.relu)) 
    model.add(keras.layers.Dropout(.3)) 
    model.add(keras.layers.Dense(class_num,activation=tf.nn.sigmoid))

    model.compile(optimizer ='adam', loss='binary_crossentropy', metrics=['accuracy'])
    model.summary()
    return model

# Train the Model
def train_model(model, train_generator, val_generator):
    hist = model.fit(train_generator, epochs=5, validation_data=val_generator)
    return hist

# Evaluate the Model
def evaluate_model(model, test_generator):
    loss, accuracy = model.evaluate(test_generator)
    print('Test Loss =', loss)
    print('Test Accuracy =', accuracy)

    y_test = test_generator.classes
    predictions = model.predict(test_generator)
    y_pred = np.where(predictions >= 0.5, 1, 0)
    y_test = np.ravel(y_test)
    y_pred = np.ravel(y_pred)
    df = pd.DataFrame({'Actual': y_test, 'Prediction': y_pred})

    return y_test, y_pred

def plot_confusion_matrix(y_test, y_pred):
    class_names=['Fractured', 'Not Fractured']
    CM = confusion_matrix(y_test,y_pred)
    sns.heatmap(CM, fmt='g', center=True, cbar=False, annot=True, cmap='Blues')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.xticks(ticks=np.arange(len(class_names)) + 0.5, labels=class_names)
    plt.yticks(ticks=np.arange(len(class_names)) + 0.5, labels=class_names)
    plt.title('Confusion Matrix')
    plt.show()

def plot_accuracy_graph(hist):
    plt.plot(hist.history['accuracy'], label='Train Accuracy')
    plt.plot(hist.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Accuracy Graph')
    plt.show()

if __name__ == "__main__":
    # Read data
    df=data('data_fracture\\train')
    train, val, test= split_data(df)

    # Create data generators
    train_generator, test_generator, val_generator = create_data_generators(train, test, val)

    # Build model
    model = build_model()

    # Train the model
    hist = train_model(model, train_generator, val_generator)

    # Evaluate the model
    y_test, y_pred = evaluate_model(model, test_generator)

    # Plot confusion matrix
    plot_confusion_matrix(y_test, y_pred)

    # Plot accuracy graph
    plot_accuracy_graph(hist)
# Out:
# Found 3544 validated image filenames belonging to 2 classes.
# Found 4432 validated image filenames belonging to 2 classes.
# Found 887 validated image filenames belonging to 2 classes.
# C:\Users\Palak Bansal\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_9 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
model.save('fracture.keras')

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import img_to_array

def predict_single_image(model, image_path):
    # Load and preprocess the image
    img = image.load_img(image_path, target_size=(224, 224))
    img_array = img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = img_array / 255.0  # Normalize the image

    # Make prediction
    prediction = model.predict(img_array)
    print(f'Raw prediction output: {prediction}')  # Debugging line

    # Interpret prediction
    probability = prediction[0][0]
    class_label = 'Fractured' if probability >= 0.5 else 'Not Fractured'
    return class_label, probability

if __name__ == "__main__":
    # Other code here...

    # Predict a single image
    image_path = 'path_to_your_image.jpg' 
    image_paths =[ 'data_fracture/val/fractured/1.jpg','data_fracture/train/fractured/18.jpg','data_fracture/train/fractured/15-rotated3-rotated1-rotated1.jpg','data_fracture/train/fractured/16-rotated2-rotated3-rotated3.jpg',
              'data_fracture/train/fractured/121.jpg','data_fracture/train/fractured/17.jpg','data_fracture/train/fractured/18.jpg','data_fracture/train/fractured/19.jpg','data_fracture/train/fractured/20.jpg',
              'data_fracture/train/fractured/35.jpg','data_fracture/train/fractured/114.jpg']  # Replace with your image path # Replace with your image path
    
    for i in image_paths:
        label, probability = predict_single_image(model,i)
        print(f'Prediction: {label}, Probability: {probability}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw prediction output: [[0.6277242]]
# Prediction: Fractured, Probability: 0.6277241706848145
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw prediction output: [[0.9392137]]
# Prediction: Fractured, Probability: 0.9392136931419373
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw prediction output: [[0.7386499]]
# Prediction: Fractured, Probability: 0.7386499047279358
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw prediction output: [[0.88034004]]
# Prediction: Fractured, Probability: 0.880340039730072
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Raw prediction output: [[0.9978743]]
# Prediction: Fractured, Probability: 0.9978743195533752
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw prediction output: [[0.86243355]]
# Prediction: Fractured, Probability: 0.8624335527420044
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Raw prediction output: [[0.9392137]]
# Prediction: Fractured, Probability: 0.9392136931419373
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ...

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(rescale=1./255)

# %%
image_size = (224, 224)
batch_size = 32

# %%
test_generator = datagen.flow_from_dataframe(
        test,
        x_col='image',
        y_col='label',
        target_size=image_size,
        batch_size=batch_size,
        class_mode='binary',
        shuffle=False
    )
# Out:
# Found 600 validated image filenames belonging to 2 classes.
